# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.dropna(axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(axis=1,thresh=800)
# Out:
# Empty DataFrame
# Columns: []
# Index: [1, 3, 6, 10, 11, 21, 23, 27, 52, 54, 62, 66, 75, 88, 92, 96, 97, 102, 110, 118, 123, 124, 136, 137, 139, 148, 151, 170, 174, 177, 183, 193, 194, 195, 205, 209, 215, 218, 224, 230, 245, 248, 251, 252, 257, 262, 263, 268, 269, 273, 275, 291, 292, 297, 299, 305, 307, 309, 310, 311, 318, 319, 325, 327, 329, 331, 332, 336, 337, 339, 340, 341, 345, 356, 366, 369, 370, 377, 390, 393, 394, 412, 429, 430, 434, 435, 438, 445, 449, 452, 453, 456, 460, 462, 473, 484, 486, 487, 492, 496, ...]
#
# [183 rows x 0 columns]

# %%
df.dropna(axis=1,thresh=800).isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
df.dropna(axis=1,how='all')
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.fillna(value="Some random value")
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.fillna(value=df["Age"].mean())
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby("Survived").describe()["PassengerId"]
# Out:
#           count        mean         std  min    25%    50%    75%    max
# Survived
# 0          60.0  402.983333  252.917183  7.0  174.0  359.0  634.5  873.0
# 1         123.0  480.918699  241.058955  2.0  309.0  497.0  690.5  890.0

# %%
df.groupby("Survived").describe()["PassengerId"].T
# Out:
# Survived           0           1
# count      60.000000  123.000000
# mean      402.983333  480.918699
# std       252.917183  241.058955
# min         7.000000    2.000000
# 25%       174.000000  309.000000
# 50%       359.000000  497.000000
# 75%       634.500000  690.500000
# max       873.000000  890.000000

# %%
df= pd.read_csv("bank.csv",delimiter=";")

# %%
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
l=[]
for i in df["education"].unique():
    l.append(df[df["education"]==i])

# %%
df1=l[0]

# %%
df1
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
df2=l[1]

# %%
df2
# Out:
#       age          job  marital  education default  balance housing loan  \
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
df3=l[2]

# %%
df3
# Out:
#       age            job   marital education default  balance housing loan  \
# 2      35     management    single  tertiary      no     1350     yes   no
# 3      30     management   married  tertiary      no     1476     yes  yes
# 5      35     management    single  tertiary      no      747      no   no
# 6      36  self-employed   married  tertiary      no      307     yes   no
# 8      41   entrepreneur   married  tertiary      no      221     yes   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4501   34     management   married  tertiary      no      297     yes   no
# 4506   42     unemployed  divorced  tertiary      no     -166      no   no
# 4509   51     technician   married  tertiary      no     2506      no   no
# 4517   57  self-employed   married  tertiary     yes    -3313     yes  yes
# 4520   44   entrepreneur    single  tertiary      no     1136     yes  yes
#
# ...

# %%
pd.concat([df2,df3])
# Out:
#       age            job   marital  education default  balance housing loan  \
# 1      33       services   married  secondary      no     4789     yes  yes
# 4      59    blue-collar   married  secondary      no        0     yes   no
# 7      39     technician   married  secondary      no      147     yes   no
# 10     39       services   married  secondary      no     9374     yes   no
# 11     43         admin.   married  secondary      no      264     yes   no
# ...   ...            ...       ...        ...     ...      ...     ...  ...
# 4501   34     management   married   tertiary      no      297     yes   no
# 4506   42     unemployed  divorced   tertiary      no     -166      no   no
# 4509   51     technician   married   tertiary      no     2506      no   no
# 4517   57  self-employed   married   tertiary     yes    -3313     yes  yes
# 4520   44   entrepreneur    single   tertiary      no     1136     yes  yes
#
# ...

# %%
df2=df2.head()

# %%
df3=df3.head()

# %%
pd.concat([df2,df3])
# Out:
#     age            job  marital  education default  balance housing loan  \
# 1    33       services  married  secondary      no     4789     yes  yes
# 4    59    blue-collar  married  secondary      no        0     yes   no
# 7    39     technician  married  secondary      no      147     yes   no
# 10   39       services  married  secondary      no     9374     yes   no
# 11   43         admin.  married  secondary      no      264     yes   no
# 2    35     management   single   tertiary      no     1350     yes   no
# 3    30     management  married   tertiary      no     1476     yes  yes
# 5    35     management   single   tertiary      no      747      no   no
# 6    36  self-employed  married   tertiary      no      307     yes   no
# 8    41   entrepreneur  married   tertiary      no      221     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y
# 1   cellular   11   may       220         1    339         4  failure  no
# ...

# %%
df1=df1.head()[["age","job","education"]]

# %%
df2=df2[["age","job","education"]]

# %%
df3=df3[["age","job","education"]]

# %%
pd.concat([df2,df3],axis=1)
# Out:
#      age          job  education   age            job education
# 1   33.0     services  secondary   NaN            NaN       NaN
# 2    NaN          NaN        NaN  35.0     management  tertiary
# 3    NaN          NaN        NaN  30.0     management  tertiary
# 4   59.0  blue-collar  secondary   NaN            NaN       NaN
# 5    NaN          NaN        NaN  35.0     management  tertiary
# 6    NaN          NaN        NaN  36.0  self-employed  tertiary
# 7   39.0   technician  secondary   NaN            NaN       NaN
# 8    NaN          NaN        NaN  41.0   entrepreneur  tertiary
# 10  39.0     services  secondary   NaN            NaN       NaN
# 11  43.0       admin.  secondary   NaN            NaN       NaN

# %%
df4=pd.concat([df2,df3],axis=1)

# %%
df4
# Out:
#      age          job  education   age            job education
# 1   33.0     services  secondary   NaN            NaN       NaN
# 2    NaN          NaN        NaN  35.0     management  tertiary
# 3    NaN          NaN        NaN  30.0     management  tertiary
# 4   59.0  blue-collar  secondary   NaN            NaN       NaN
# 5    NaN          NaN        NaN  35.0     management  tertiary
# 6    NaN          NaN        NaN  36.0  self-employed  tertiary
# 7   39.0   technician  secondary   NaN            NaN       NaN
# 8    NaN          NaN        NaN  41.0   entrepreneur  tertiary
# 10  39.0     services  secondary   NaN            NaN       NaN
# 11  43.0       admin.  secondary   NaN            NaN       NaN

# %%
df4["age"]
# Out:
#      age   age
# 1   33.0   NaN
# 2    NaN  35.0
# 3    NaN  30.0
# 4   59.0   NaN
# 5    NaN  35.0
# 6    NaN  36.0
# 7   39.0   NaN
# 8    NaN  41.0
# 10  39.0   NaN
# 11  43.0   NaN

# %%
df4.iloc[:,3]
# Out:
# 1      NaN
# 2     35.0
# 3     30.0
# 4      NaN
# 5     35.0
# 6     36.0
# 7      NaN
# 8     41.0
# 10     NaN
# 11     NaN
# Name: age, dtype: float64

# %%
df1.iloc[[1,2],[0,2]]
# Out:
#     age  marital
# 9    43  married
# 18   25   single

# %%
pd.merge(df2,df3)
# Out:
# Empty DataFrame
# Columns: [age, job, education]
# Index: []

# %%
pd.merge(df1,df2,on="age")
# Out:
#      age        job_x education_x        job_y education_y
# 0     43     services     primary       admin.   secondary
# 1     43  blue-collar     primary       admin.   secondary
# 2     43     services     primary       admin.   secondary
# 3     43  blue-collar     primary       admin.   secondary
# 4     43   management     primary       admin.   secondary
# ..   ...          ...         ...          ...         ...
# 101   59   management     primary  blue-collar   secondary
# 102   59  blue-collar     primary  blue-collar   secondary
# 103   59  blue-collar     primary  blue-collar   secondary
# 104   59      retired     primary  blue-collar   secondary
# 105   59    housemaid     primary  blue-collar   secondary
#
# [106 rows x 5 columns]

# %%
pd.merge(df1,df2,on="age")
# Out:
#    age     job_x education_x   job_y education_y
# 0   43  services     primary  admin.   secondary

# %%
pd.merge(df1,df2,on="age",how="outer")
# Out:
#    age        job_x education_x        job_y education_y
# 0   30   unemployed     primary          NaN         NaN
# 1   43     services     primary       admin.   secondary
# 2   25  blue-collar     primary          NaN         NaN
# 3   55  blue-collar     primary          NaN         NaN
# 4   78      retired     primary          NaN         NaN
# 5   33          NaN         NaN     services   secondary
# 6   59          NaN         NaN  blue-collar   secondary
# 7   39          NaN         NaN   technician   secondary
# 8   39          NaN         NaN     services   secondary
